# %% [markdown]
# # copy
#
# ---
#
# `a`という名前のリストや辞書を編集したい場合、いったん別の名前の変数である`b`に、`=`を使って格納するとします。
# その後`b`だけ編集した場合、pythonでは元の`a`も同様に編集されてしまいます。

# %%
a = ['a', 'b', 'c', 'd']
b = a
a[0] = 'e'
print('リストa', a, id(a))
print('リストb', b, id(b))
# Out:
# リストa ['e', 'b', 'c', 'd'] 4560346368
# リストb ['e', 'b', 'c', 'd'] 4560346368

# %% [markdown]
# `b = a`でリスト`a`をリスト`b`にコピー(?)してから、リスト`a`の最初の要素を`e`に変更しました。
# しかし、リスト`b`の最初の要素も`e`に変更されてしまっていることがわかります。

# %%
a = {'A': 1, 'B': 2, 'C':3, 'D': 4}
b = a
b['A'] = 4
print('辞書a', a, id(a))
print('辞書b', b, id(b))
# Out:
# 辞書a {'A': 4, 'B': 2, 'C': 3, 'D': 4} 4560988352
# 辞書b {'A': 4, 'B': 2, 'C': 3, 'D': 4} 4560988352

# %% [markdown]
# 辞書の場合でも同様です。
# 辞書`b`のキー`A`の値を`4`に変更すると、辞書`a`のキー`A`の値も`4`になってしまいました。

# %% [markdown]
# ---
# `sorted()`を使って、リスト`a`を降順にソートしたものをリスト`b`に格納してから、リスト`b`の要素を変更してみます。

# %%
a = ['a', 'b', 'c', 'd']
b = sorted(a, reverse=True)
print('リストa', a, id(a))
print('リストb', b, id(b))
# Out:
# リストa ['a', 'b', 'c', 'd'] 4560279040
# リストb ['d', 'c', 'b', 'a'] 4560346368

# %% [markdown]
# このように、sorted()関数を使って処理したものを他の変数に格納すれば、独立した変数として処理することができます。

# %%
a = ['a', 'b', 'c', 'd']
b = a
b.sort(reverse=True)
print('リストa', a, id(a))
print('リストb', b, id(b))
# Out:
# リストa ['d', 'c', 'b', 'a'] 4559733184
# リストb ['d', 'c', 'b', 'a'] 4559733184

# %% [markdown]
# しかし、いったんリスト`a`をリスト`b`に代入した後に、リストのメソッドである`sort`を使った場合は、同一のオブジェクトとして扱われるようです。

# %% [markdown]
# ---
#
# オブジェクトをコピーしたい場合は、`copy`モジュールの`copy`メソッドを使用します。

# %%
import copy
a = ['a', 'b', 'c', 'd']
b = copy.copy(a)
b[0] = 'e'
print('リストa', a, id(a))
print('リストb', b, id(b))
# Out:
# リストa ['a', 'b', 'c', 'd'] 4560800832
# リストb ['e', 'b', 'c', 'd'] 4559874688

# %% [markdown]
# リスト`a`とリスト`b`を独立して処理することができました。

# %%
a = ['a', 'b', 'c', 'd']
b = copy.copy(a)
b.sort(reverse=True)
print('リストa', a, id(a))
print('リストb', b, id(b))
# Out:
# リストa ['a', 'b', 'c', 'd'] 4560302272
# リストb ['d', 'c', 'b', 'a'] 4559733184

# %% [markdown]
# `copy`メソッドでコピーしたあと、リスト`b`を`sort`メソッドで編集すれば、リスト`a`とリスト`b`を独立に扱うことができました。

# %%
a = {'a': 1, 'b': 2, 'c':3, 'd': 4}
a.setdefault('e', {})
a['e'].setdefault('x', 5)
print(a)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5}}

# %%
a = {'a': 1, 'b': 2, 'c':3, 'd': 4}
a.setdefault('e', {})
a['e'].setdefault('x', 5)
a['e'].setdefault('y', 6)

b = copy.copy(a)
print('辞書a', a, id(a))
print('辞書b', b, id(b))

b['e']['x'] = 10
print('辞書a', a, id(a))
print('辞書b', b, id(b))
# Out:
# 辞書a {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5, 'y': 6}} 4561089792
# 辞書b {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5, 'y': 6}} 4561089664
# 辞書a {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 10, 'y': 6}} 4561089792
# 辞書b {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 10, 'y': 6}} 4561089664

# %%
a = {'a': 1, 'b': 2, 'c':3, 'd': 4}
a.setdefault('e', {})
a['e'].setdefault('x', 5)
a['e'].setdefault('y', 6)

b = copy.deepcopy(a)
print('辞書a', a, id(a))
print('辞書b', b, id(b))

b['e']['x'] = 10
print('辞書a', a, id(a))
print('辞書b', b, id(b))
# Out:
# 辞書a {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5, 'y': 6}} 4561038784
# 辞書b {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5, 'y': 6}} 4561037184
# 辞書a {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 5, 'y': 6}} 4561038784
# 辞書b {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': {'x': 10, 'y': 6}} 4561037184

# %%
a = 'tokyo'
b = a
print('文字a', a, id(a))
print('文字b', b, id(b))

b = 'osaka'
print('文字a', a, id(a))
print('文字b', b, id(b))
# Out:
# 文字a tokyo 4561036848
# 文字b tokyo 4561036848
# 文字a tokyo 4561036848
# 文字b osaka 4561035440
